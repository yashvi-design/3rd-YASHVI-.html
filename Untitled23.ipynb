# %% [markdown]
# <a href="https://colab.research.google.com/github/yashvi-design/3rd-YASHVI-.html/blob/main/Untitled23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
with open('Codingal.txt', 'w')as file:
  file.write("Hi! I am Penguin and I am 1 yr old.")
file.close()

with open('Codingal.txt', 'r')as file:
  data = file.readlines()
  print("Words in this file are....")
  for line in data:
    word = line.split()
    print (word)
file.close()
# Out:
# Words in this file are....
# ['Hi!', 'I', 'am', 'Penguin', 'and', 'I', 'am', '1', 'yr', 'old.']

# %%
new_file = open('New_File.txt', 'x')
new_file.close()

import os
print("Checking if my_file exists or not....")
if os.path.exists("my_file.txt"):
  os.remove("my_file.txt")
else:
  print("The file does not exists")

my_file = open("my_file.txt", "w")
my_file.write("Hi! I am Penguin and I am 1 yr old.")
my_file.close()
# Out:
# Checking if my_file exists or not....
# The file does not exists

# %%
outputFile = open('UpdatedFile.txt', "w")
inputFile = open('Repeated.txt', "r")

lines_seen_so_far = set()
print("Eliminating duplicate lines....")

for line in inputFile:
  if line not in lines_seen_so_far:

    outputFile.write(line)
    lines_seen_so_far.add(line)
inputFile.close()
outputFile.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-4132278231.py in <cell line: 0>()
#       1 outputFile = open('UpdatedFile.txt', "w")
# ----> 2 inputFile = open('Repeated.txt', "r")
#       3
#       4 lines_seen_so_far = set()
#       5 print("Eliminating duplicate lines....")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Repeated.txt'

# %%
with open('Codingal.txt') as fp:
  data1 = fp.read()
with open('sample_doc.txt') as fp:
  data2 = fp.read()

data1 += "\n"
data1 += data2
print("Merging two files....")
with open('MergedFile.txt', 'w') as fp:
  fp.write(data1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3101128866.py in <cell line: 0>()
#       1 with open('Codingal.txt') as fp:
#       2   data1 = fp.read()
# ----> 3 with open('sample_doc.txt') as fp:
#       4   data2 = fp.read()
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sample_doc.txt'
