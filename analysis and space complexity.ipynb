# %% [markdown]
# <a href="https://colab.research.google.com/github/yashvi-design/3rd-YASHVI-.html/blob/main/analysis%20and%20space%20complexity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def prints(n):
    if(n<=0):
       return
    print("Codingal")
    prints(n/2)
    prints(n/2)

# %%
def sum(n):
    return n*(n+1)/2

def arraysum(a):
    sum=0
    for i in a:
        sum = sum + i

    return (sum)

a = [12, 3, 4, 15]
arraysum(a)

def summ(n):
    if(n<=0):
       return
    return n+ summ(n-1)

# %%
def text(a):
    sum=0
    for i in a:
        sum = sum + i

    return(sum)

a = [15, 18, 20, 30, 2]

left = 0
right = len(a) - 1
while left < right:
    a[left], a[right] = a[right], a[left]
    left += 1
    right -= 1


def arraysum(a):
     sum=0
     for i in a:
        sum = sum + i

        return(sum)
a = [12, 13, 2, 20]

seen_numbers = set()

for num in a:
    if num in seen_numbers:
         True
    seen_numbers.add(num)

def tree_height(root):
     if not root:
        return 0
     return 1 + max(tree_height(root.left), tree_height(root.right))

def vertices_func(input_a):
    vertices = [
        (0,0), #Veterx A
        (1,0), #Vertex B
        (2,1), #Vertex C
    ]


distance = [[float('inf')] * num_vertices for _ in range(num_vertices)]
for i in range(num_vertices):
    distance[i][i] = 0
